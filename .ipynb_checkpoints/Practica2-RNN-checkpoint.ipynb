# %% [markdown]
# <div style="color:#3c4d5a; border-top: 7px solid #42A5F5; border-bottom: 7px solid #42A5F5; padding: 5px; text-align: center; text-transform: uppercase"><h1>Redes Neuronales Recurrentes - Practica </h1> </div>

# %% [markdown]
# ### **Integrantes:** Diego Bravo & Ariel Paltan
# ### **Carrera:** Computación

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 4px solid #4E853C; width: 100%; margin-bottom: 15px; padding-bottom: 2px"><h2>Importar Módulos</h2> </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import os
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_absolute_error
import tf2onnx
import tensorflow as tf

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 4px solid #4E853C; width: 100%; margin-bottom: 15px; padding-bottom: 2px"><h2>Generación Dataset</h2> </div>

# %%
num_dias = 60

productos = [
    {"id": 101, "nombre": "Leche Entera 1L", "cat": "Lácteos", "un": "Caja", "st_ini": 500, "tasa_base": 30},
    {"id": 102, "nombre": "Arroz Blanco 1kg", "cat": "Granos", "un": "Bolsa", "st_ini": 1200, "tasa_base": 45},
    {"id": 103, "nombre": "Aceite Vegetal 900ml", "cat": "Abarrotes", "un": "Botella", "st_ini": 300, "tasa_base": 15},
    {"id": 104, "nombre": "Pasta 500g", "cat": "Abarrotes", "un": "Paquete", "st_ini": 450, "tasa_base": 20},
    {"id": 105, "nombre": "Café Molido 250g", "cat": "Bebidas", "un": "Sobre", "st_ini": 200, "tasa_base": 10},
    {"id": 106, "nombre": "Detergente Líquido 3L", "cat": "Limpieza", "un": "Bidón", "st_ini": 150, "tasa_base": 5},
    {"id": 107, "nombre": "Atún en Conserva 140g", "cat": "Enlatados", "un": "Lata", "st_ini": 800, "tasa_base": 35},
    {"id": 108, "nombre": "Huevos (Docena)", "cat": "Fresco", "un": "Cartón", "st_ini": 100, "tasa_base": 12},
    {"id": 109, "nombre": "Harina de Trigo 1kg", "cat": "Granos", "un": "Bolsa", "st_ini": 600, "tasa_base": 18},
    {"id": 110, "nombre": "Papel Higiénico 4u", "cat": "Higiene", "un": "Pack", "st_ini": 400, "tasa_base": 25},
]

sales_data = []
inventory_state = {p['id']: p['st_ini'] for p in productos}
fecha_inicio = datetime(2026, 3, 7)

for i in range(num_dias):
    fecha = fecha_inicio + timedelta(days=i)
    is_weekend = fecha.weekday() >= 5
    
    for p in productos:
        venta_proyectada = int(np.random.poisson(lam=p['tasa_base'] * (1.5 if is_weekend else 1.0)))
        
        stock_en_momento = inventory_state[p['id']]
        venta_real = min(venta_proyectada, stock_en_momento)
        
        sales_data.append([p['id'], p['nombre'], fecha.strftime('%Y-%m-%d'), venta_real, stock_en_momento])
        nuevo_stock = stock_en_momento - venta_real
        if nuevo_stock < (p['st_ini'] * 0.15): 
            nuevo_stock += p['st_ini'] // 2   
            
        inventory_state[p['id']] = nuevo_stock

df_sales = pd.DataFrame(sales_data, columns=['product_id', 'nombre', 'fecha_venta', 'cantidad_vendida', 'stock_en_momento'])
df_sales.to_csv('data/sales_history.csv', index=False)

df_inventory = pd.DataFrame([[p['id'], p['nombre'], p['cat'], p['un'], inventory_state[p['id']], '2025-12-31'] for p in productos], 
                             columns=['product_id', 'nombre', 'categoria', 'unidad', 'stock_actual', 'fecha_expiracion'])
df_inventory.to_csv('data/inventory.csv', index=False)

# %% [markdown]
# La generación de datos se realiza mediante una simulación de ventas diarias para distintos productos durante 60 días. Para cada producto, las ventas se generan aleatoriamente utilizando una distribución de Poisson basada en una tasa promedio de demanda, incrementando las ventas durante los fines de semana. Además, el sistema controla el stock disponible, descuenta las ventas realizadas y aplica un reabastecimiento automático cuando el inventario cae por debajo del 15% del stock inicial.

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 8px solid #E67129; width: 100%; margin-bottom: 10px; padding-bottom: 2px">
#     <h2><strong>Fase 1: Análisis y Preparación del Dataset</strong></h2>
# </div>

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 4px solid #4E853C; width: 100%; margin-bottom: 15px; padding-bottom: 2px"><h2>Cargar Dataset</h2> </div>

# %%
df = pd.read_csv('data/sales_history.csv')

df['fecha_venta'] = pd.to_datetime(df['fecha_venta'])

df.head()
# Out:
#    product_id                nombre fecha_venta  cantidad_vendida  \
# 0         101       Leche Entera 1L  2026-03-07                45
# 1         102      Arroz Blanco 1kg  2026-03-07                81
# 2         103  Aceite Vegetal 900ml  2026-03-07                19
# 3         104            Pasta 500g  2026-03-07                26
# 4         105      Café Molido 250g  2026-03-07                13
#
#    stock_en_momento
# 0               500
# 1              1200
# 2               300
# 3               450
# 4               200

# %%
df.describe()
# Out:
#        product_id          fecha_venta  cantidad_vendida  stock_en_momento
# count  600.000000                  600        600.000000        600.000000
# mean   105.500000  2026-04-05 12:00:00         24.776667        217.291667
# min    101.000000  2026-03-07 00:00:00          1.000000         16.000000
# 25%    103.000000  2026-03-21 18:00:00         13.000000         81.000000
# 50%    105.500000  2026-04-05 12:00:00         22.000000        164.500000
# 75%    108.000000  2026-04-20 06:00:00         34.000000        288.750000
# max    110.000000  2026-05-05 00:00:00         81.000000       1200.000000
# std      2.874678                  NaN         15.268005        188.666518

# %% [markdown]
# ### TOTAL VENDIDO DE LOS PRODUCTOS
# ---

# %%
ventas  = df.groupby('nombre')['cantidad_vendida'].sum().sort_values(ascending=False)

plt.figure(figsize=(15,6))
sns.barplot(x=ventas.values, y=ventas.index)
plt.title('Total vendido de los Productos', fontsize=15)
plt.xlabel('Cantidad')
plt.ylabel('Producto')
plt.show()

# %% [markdown]
# Se evidencia que el Arroz Blanco (1kg) lidera ampliamente las ventas con más de 3,000 unidades. Le siguen el Atún en Conserva y la Leche Entera, destacando la alta demanda de productos básicos. En un nivel intermedio se encuentran productos como papel higiénico, pasta y harina, sin embargo el Detergente Líquido (3L) presenta la menor demanda, con menos de 500 unidades vendidas.

# %% [markdown]
# ### PROMEDIO DE VENTAS POR DIA DE LA SEMANA
# ---

# %%
df['dia_nombre'] = df['fecha_venta'].dt.day_name()
df['dia_num'] = df['fecha_venta'].dt.weekday 

promdia = df.groupby(['dia_num', 'dia_nombre'])['cantidad_vendida'].mean().reset_index()
promdia = promdia.sort_values('dia_num')

plt.figure(figsize = (12,6))
sns.barplot(data=promdia, x='dia_nombre', y='cantidad_vendida', palette='Blues_d')
plt.title('Promedio de ventas por día de la semana')
plt.xlabel('Día')
plt.ylabel('Ventas promedio')
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_28852\2682711922.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=promdia, x='dia_nombre', y='cantidad_vendida', palette='Blues_d')

# %% [markdown]
# El gráfico muestra que las ventas aumentan significativamente durante el fin de semana, especialmente el sábado y domingo, superando las 30 unidades promedio. De lunes a viernes, las ventas se mantienen estables entre 20 y 23 unidades, siendo martes y jueves los días de menor actividad. Este patrón refleja un comportamiento típico de retail, donde los clientes realizan más compras en los días de descanso.

# %% [markdown]
# ### TOP 4 PRODUCTOS MÁS VENDIDOS SEGÚN EL DÍA
# ---

# %%
ventas_prod = df.groupby(['dia_nombre', 'dia_num', 'nombre'])['cantidad_vendida'].sum().reset_index()

top_por_dia = ventas_prod.sort_values(['dia_num', 'cantidad_vendida'], ascending=[True, False]).groupby('dia_nombre').head(4)

plt.figure(figsize = (15,7))
sns.barplot(data=top_por_dia, x='dia_nombre', y='cantidad_vendida', hue='nombre')
plt.title('Top 4 Productos más vendidos según el día')
plt.xlabel('Día')
plt.ylabel('Total Vendido')
plt.legend(title='Producto', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# Se evidencia una relación proporcional entre las ventas y la cantidad demandada de productos. Durante toda la semana, los productos con mayor nivel de ventas son el arroz y el atún, lo que refleja una alta demanda constante. Por ello, se recomienda mantener un stock suficiente de estos productos para evitar desabastecimientos y garantizar la disponibilidad para los clientes.

# %% [markdown]
# ### MAPA DE CALOR (CANTIDAD DE VENTAS POR DIA)
# ---

# %%
dias_ordenados = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

pivot = df.pivot_table(index='dia_nombre', columns='nombre', values='cantidad_vendida', aggfunc='sum').reindex(dias_ordenados)

plt.figure(figsize = (15,8))
sns.heatmap(pivot, cmap='YlGnBu', annot=True, fmt=".0f")
plt.title('Intensidad de Ventas por Producto y Día')
plt.xlabel('Producto')
plt.ylabel('Día de la Semana')
plt.show()

# %% [markdown]
# El mapa de calor muestra que el Arroz Blanco 1kg es el producto con mayor nivel de ventas, especialmente durante el fin de semana. En general, sábado y domingo presentan un incremento notable en la demanda de casi todos los productos. El Atún en Conserva y la Leche Entera mantienen ventas constantes durante la semana y aumentan aún más los fines de semana. Por otro lado, productos como el Detergente Líquido 3L y el Café Molido presentan menor rotación. Además, el lunes destaca como el día más fuerte entre los días laborables para algunos productos básicos.

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 4px solid #4E853C; width: 100%; margin-bottom: 15px; padding-bottom: 2px"><h2>Feature Engineering: Variables temporales</h2> </div>

# %%
df['dia_semana'] = df['fecha_venta'].dt.dayofweek
df['mes'] = df['fecha_venta'].dt.month
df['fin_de_semana'] = (df['dia_semana'] >= 5).astype(int)

df = df.sort_values(by=['product_id', 'fecha_venta'])
df['ventas_lag_1'] = df.groupby('product_id')['cantidad_vendida'].shift(1) #Venta hace 1 dia
df['ventas_lag_2'] = df.groupby('product_id')['cantidad_vendida'].shift(2) #Venta hace 2 dias

df['media_movil_7d'] = df.groupby('product_id')['cantidad_vendida'].rolling(window=7).mean().reset_index(0, drop=True) #Promedio de la semana
df = df.fillna(0)

df.head(10)
# Out:
#     product_id           nombre fecha_venta  cantidad_vendida  \
# 0          101  Leche Entera 1L  2026-03-07                45
# 10         101  Leche Entera 1L  2026-03-08                48
# 20         101  Leche Entera 1L  2026-03-09                33
# 30         101  Leche Entera 1L  2026-03-10                16
# 40         101  Leche Entera 1L  2026-03-11                29
# 50         101  Leche Entera 1L  2026-03-12                28
# 60         101  Leche Entera 1L  2026-03-13                24
# 70         101  Leche Entera 1L  2026-03-14                52
# 80         101  Leche Entera 1L  2026-03-15                46
# 90         101  Leche Entera 1L  2026-03-16                35
#
#     stock_en_momento dia_nombre  dia_num  dia_semana  mes  fin_de_semana  \
# 0                500   Saturday        5           5    3              1
# 10               455     Sunday        6           6    3              1
# ...

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 4px solid #4E853C; width: 100%; margin-bottom: 15px; padding-bottom: 2px"><h2>Normalización</h2> </div>

# %%
columnas = ['stock_en_momento', 'dia_semana', 'mes', 'fin_de_semana', 'ventas_lag_1', 'ventas_lag_2', 'media_movil_7d']
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 4px solid #4E853C; width: 100%; margin-bottom: 15px; padding-bottom: 2px"><h2>Ventana Temporal de 7 Días</h2> </div>

# %%
fechas = df['fecha_venta'].sort_values().unique()
fecha_split = fechas[int(len(fechas) * 0.7)]

df_train = df[df['fecha_venta'] <= fecha_split].copy()
df_test = df[df['fecha_venta'] > fecha_split].copy()

df_train[columnas] = scaler_X.fit_transform(df_train[columnas])
df_train['cantidad_vendida_scaled'] = scaler_y.fit_transform(df_train[['cantidad_vendida']])

df_test[columnas] = scaler_X.transform(df_test[columnas])
df_test['cantidad_vendida_scaled'] = scaler_y.transform(df_test[['cantidad_vendida']])

pasos = 7

def crear_secuencias(df_data):
    X_seq, y_seq = [], []
    for pid in df_data['product_id'].unique():
        datos = df_data[df_data['product_id'] == pid][columnas].values
        ventas = df_data[df_data['product_id'] == pid]['cantidad_vendida_scaled'].values
        if len(datos) > pasos:
            for i in range(len(datos) - pasos):
                X_seq.append(datos[i : i + pasos])
                y_seq.append(ventas[i + pasos])
                
    return np.array(X_seq), np.array(y_seq)

X_train, y_train = crear_secuencias(df_train)
X_test, y_test = crear_secuencias(df_test)

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 8px solid #E67129; width: 100%; margin-bottom: 10px; padding-bottom: 2px">
#     <h2><strong>Fase 2: Desarrollo y Entrenamiento de Modelos</strong></h2>
# </div>

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 4px solid #4E853C; width: 100%; margin-bottom: 15px; padding-bottom: 2px"><h2>Entrenamiento Modeo - RNN - LSTM</h2> </div>

# %%
modelo = Sequential([
    LSTM(32, activation='relu', input_shape=(pasos, len(columnas))),
    Dense(16, activation='relu'),
    Dense(1)
])

modelo.compile(optimizer='adam', loss='mse')

e_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

modelo.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), 
           callbacks=[e_stop], batch_size=16, verbose=0)

predic = scaler_y.inverse_transform(modelo.predict(X_test, verbose=0))
ytest_r = scaler_y.inverse_transform(y_test.reshape(-1, 1))

rmse = np.sqrt(mean_squared_error(ytest_r, predic))
r2 = r2_score(ytest_r, predic)
mape = mean_absolute_percentage_error(ytest_r, predic)
mae = mean_absolute_error(ytest_r, predic)

print("--- EVALUACIÓN FINAL DEL MODELO ---")
print(f"Precisión del Modelo (R² Score): {r2*100:.2f}%")
print(f"Error Promedio en Unidades (MAE): {mae:.2f} unidades")
print(f"Error Porcentual (MAPE): {mape*100:.2f}%")
print(f"RMSE (Error Cuadrático): {rmse:.2f}")
print(f"Modelo entrenado. RMSE en test: {rmse:.2f}")
# Out:
# C:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# --- EVALUACIÓN FINAL DEL MODELO ---
# Precisión del Modelo (R² Score): 85.74%
# Error Promedio en Unidades (MAE): 4.06 unidades
# Error Porcentual (MAPE): 24.77%
# RMSE (Error Cuadrático): 5.90
# Modelo entrenado. RMSE en test: 5.90

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 8px solid #E67129; width: 100%; margin-bottom: 10px; padding-bottom: 2px">
#     <h2><strong>Fase 3: Función de Predicción y Preparación para Despliegue</strong></h2>
# </div>

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 4px solid #4E853C; width: 100%; margin-bottom: 15px; padding-bottom: 2px"><h2>Funciones de Predicción</h2> </div>

# %% [markdown]
# Se una función de predicción de demanda que utiliza los últimos 7 registros de ventas de un producto para generar estimaciones futuras mediante el modelo entrenado. Además, permite realizar predicciones para fechas posteriores de forma iterativa, agregando cada predicción al historial temporal y recalculando variables como rezagos de ventas para mantener la secuencia de datos.

# %%
def predecir_demanda(product_id, fecha_str):
    fecha_objetivo = pd.to_datetime(fecha_str)
    df_prod = df[df['product_id'] == product_id].copy()
    
    if df_prod.empty:
        return 0
        
    fecha_maxima_real = df_prod['fecha_venta'].max()
    
    if fecha_objetivo <= fecha_maxima_real + pd.Timedelta(days=1):
        filtro = df_prod['fecha_venta'] < fecha_objetivo
        historial = df_prod[filtro].sort_values('fecha_venta').tail(pasos)
        
        if len(historial) < pasos: return 0
        
        datos_escalados = scaler_X.transform(historial[columnas])
        X_pred = datos_escalados.reshape(1, pasos, len(columnas))
        pred_scaled = modelo.predict(X_pred, verbose=0)
        pred_real = scaler_y.inverse_transform(pred_scaled)[0][0]
        
        return max(0, int(round(pred_real)))

    dias_a_predecir = (fecha_objetivo - fecha_maxima_real).days
    fecha_actual = fecha_maxima_real
    
    for _ in range(dias_a_predecir):
        ultimos_7 = df_prod.tail(pasos).copy()
        
        datos_escalados = scaler_X.transform(ultimos_7[columnas])
        X_pred = datos_escalados.reshape(1, pasos, len(columnas))
        pred_scaled = modelo.predict(X_pred, verbose=0)
        pred_real = max(0, int(round(scaler_y.inverse_transform(pred_scaled)[0][0])))
        
        fecha_actual += pd.Timedelta(days=1)
        
        if fecha_actual == fecha_objetivo:
            return pred_real
            
        nuevo_registro = pd.DataFrame([{
            'fecha_venta': fecha_actual,
            'product_id': product_id,
            'cantidad_vendida': pred_real,
            'dia_semana': fecha_actual.dayofweek,
            'mes': fecha_actual.month,
            'fin_de_semana': int(fecha_actual.dayofweek >= 5),
            'stock_en_momento': max(0, ultimos_7.iloc[-1]['stock_en_momento'] - pred_real)
        }])
        
        df_prod = pd.concat([df_prod, nuevo_registro], ignore_index=True)
        
        df_prod['ventas_lag_1'] = df_prod['cantidad_vendida'].shift(1).fillna(0)
        df_prod['ventas_lag_2'] = df_prod['cantidad_vendida'].shift(2).fillna(0)
        df_prod['media_movil_7d'] = df_prod['cantidad_vendida'].rolling(window=7).mean().fillna(0)
        
    return 0


def predecir_demanda_lista(lista_productos, fecha_str):
    resultados = {}
    for pid in lista_productos:
        resultados[pid] = predecir_demanda(pid, fecha_str)
    return resultados

# %%
pred_101 = predecir_demanda(101, '2026-05-10')

print(f"\nProducto ID: 101")
print(f"Fecha       : 2024-05-06")
print(f"Demanda Est.: {pred_101} unidades")

print("\n" + "-"*50)

predicciones = predecir_demanda_lista([101,103, 105,108,109], '2026-05-10')

print("\nPredicción múltiple de productos:\n")

for prod_id, demanda in predicciones.items():
    print(f"• Producto {prod_id}: {demanda} unidades")
# Out:
# Producto ID: 101
# Fecha       : 2024-05-06
# Demanda Est.: 40 unidades
#
# --------------------------------------------------
#
# Predicción múltiple de productos:
#
# • Producto 101: 40 unidades
# • Producto 103: 22 unidades
# • Producto 105: 12 unidades
# • Producto 108: 15 unidades
# • Producto 109: 26 unidades

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 4px solid #4E853C; width: 100%; margin-bottom: 15px; padding-bottom: 2px"><h2>Conclusiones</h2> </div>

# %% [markdown]
# La implementación de redes LSTM demostró ser efectiva para la predicción de demanda y la gestión de inventarios, ya que permite identificar patrones temporales y estacionales en las ventas, especialmente durante fines de semana. El modelo logró anticipar la demanda de productos con alta rotación, optimizando el control de stock y reduciendo riesgos de desabastecimiento. Además, mediante técnicas de normalización y métricas de error como MSE y MAE, se obtuvo un entrenamiento estable y predicciones confiables. En conjunto, el uso de LSTM transforma los datos históricos en una herramienta estratégica para mejorar la eficiencia operativa y la toma de decisiones.

# %% [markdown]
# <div id="RNN" style="color:#37475a; border-bottom: 4px solid #4E853C; width: 100%; margin-bottom: 15px; padding-bottom: 2px"><h2>Referencias</h2> </div>
#
#
# Arones Huayta, J. L., & Pillaca Riveros, J. A. (2020). Predicción de la demanda de productos de primera necesidad utilizando redes neuronales recurrentes [Tesis de título profesional, Universidad Nacional de San Cristóbal de Huamanga]. Alicia: Repositorio Nacional Digital de Ciencia, Tecnología e Innovación de Acceso Abierto. https://alicia.concytec.gob.pe/vufind/Record/RNAP_19d10241a7b882d57ba0a7498ef9370d
#
# Duque, J. C. (2021, 10 de mayo). Redes LSTM: una explicación detallada. Codificando Bits. https://codificandobits.com/blog/redes-lstm/
